# %% [markdown]
# 5 NUMBER SUMMARY AND BOX PLOT

# %%
#minimum,maximum,median,Q1,Q3,IQR

# %%
import numpy as np

# %%
lst_marks=[45,43,23,54,23,12,56]
minimum,Q1,median,Q3,maximum=np.quantile(lst_marks,[0,0.25,0.50,0.75,1.0])
minimum,Q1,median,Q3,maximum
# Out:
# (np.float64(12.0),
#  np.float64(23.0),
#  np.float64(43.0),
#  np.float64(49.5),
#  np.float64(56.0))

# %%
IQR=Q3-Q1
print(IQR)
# Out:
# 26.5

# %%
lower_fence=Q1-1.5*(IQR)
higher_fence=Q3+1.5*(IQR)
lower_fence
# higher_fence
# Out:
# np.float64(-16.75)

# %%
import seaborn as sns

# %%
sns.boxplot(lst_marks)
# Out:
# <Axes: >

# %%
lst_marks=[-17,-20,45,43,23,54,23,12,56,150,160]

# %%
sns.boxplot(lst_marks)  #dots shown are outliers
# Out:
# <Axes: >
