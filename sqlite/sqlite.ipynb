# %% [markdown]
# SQL(STRUCTURED QUERY LANGUAGE):it is a standard language for managing and manipulating relational databases.
# SQLITE:it is a self contained ,serverless and zero-configuration database engine that is widely used for embedded databases system

# %%
#by default in Python three right SQL light comes installed.
import sqlite3

# %%
#connect to an sqlite database
connection = sqlite3.connect(r"E:\udemy\example.db")
cursor = connection.cursor()

# %%
cursor=connection.cursor()

# %%
#create a table
cursor.execute('''Create table If not exists employees(
               id Integer Primary Key,
               name Text Not Null,
               age Integer,
               department text
               )'''
    )
##commit the changes
connection.commit()

# %%
cursor.execute('''
Select *from employees
    '''
    )

# %%
#insert the data in sqlite table
cursor.execute('''
Insert Into employees (name,age,department)
               values('krish',32,'data scientist')''')

cursor.execute('''
Insert Into employees (name,age,department)
               values('bob',31,'data analyst')''')

cursor.execute('''
Insert Into employees (name,age,department)
               values('atharv',30,'webd')''')
#commit the changes
connection.commit()

# %%
#query the data from table
cursor.execute('Select * from employees')
rows=cursor.fetchall()
#print the data
for row in rows:
    print(row)
# Out:
# (1, 'krish', 32, 'data scientist')
# (2, 'bob', 31, 'data analyst')
# (3, 'atharv', 30, 'webd')

# %%
cursor.execute("PRAGMA table_info(employees)")
print(cursor.fetchall())
# Out:
# [(0, 'id', 'INTEGER', 0, None, 1), (1, 'name', 'TEXT', 1, None, 0), (2, 'age', 'INTEGER', 0, None, 0), (3, 'department', 'TEXT', 0, None, 0)]

# %%
#update data inside the table
cursor.execute(''' 
UPDATE employees
Set age=34
where name='krish'
''')
connection.commit()

# %%
cursor.execute('Select * from employees')
rows=cursor.fetchall()
#print the data
for row in rows:
    print(row)
# Out:
# (1, 'krish', 34, 'data scientist')
# (2, 'bob', 31, 'data analyst')
# (3, 'atharv', 30, 'webd')

# %%
#delete data from table
cursor.execute(''' 
DELETE from employees
where name='krish'
''')
connection.commit()

# %%
cursor.execute('Select * from employees')
rows=cursor.fetchall()
#print the data
for row in rows:
    print(row)
# Out:
# (2, 'bob', 31, 'data analyst')
# (3, 'atharv', 30, 'webd')

# %%
#working with sales data
#connect to an sqlite database
connection=sqlite3.connect('sales_data.db')
cursor=connection.cursor()

#create a table for sales data
cursor.execute('''
CREATE TABLE IF NOT EXISTS sales(
               id INTEGER PRIMARY KEY,
               date TEXT NOT NULL,
               product TEXT NOT NULL,
               sales INTEGER,
               region TEXT)
 ''')

#insert data into the sales table
sales_data=[
    ('2023-01-23','product1',100,'north'),
    ('2023-01-24','product2',200,'south'),
    ('2023-01-25','product3',300,'east')
]
cursor.executemany('''INSERT into sales(date,product,sales,region)
                   values(?,?,?,?) ''',sales_data)
connection.commit()

# %%
#query the data from table
cursor.execute('Select * from sales')
rows=cursor.fetchall()
#print the data
for row in rows:
    print(row)
# Out:
# (1, '2023-01-23', 'product1', 100, 'north')
# (2, '2023-01-24', 'product2', 200, 'south')
# (3, '2023-01-25', 'product3', 300, 'east')

# %%
#close the connection
connection.close()

# %%
#query the data from table
cursor.execute('Select * from sales')
rows=cursor.fetchall()
#print the data
for row in rows:
    print(row)

##GIVE ERROR BECAUSE WE ALREADY CLOSED THE CONNECTION
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# Cell In[34], line 2
#       1 #query the data from table
# ----> 2 cursor.execute('Select * from sales')
#       3 rows=cursor.fetchall()
#       4 #print the data
#
# ProgrammingError: Cannot operate on a closed database.
