# %%
import pandas as pd

# %%
df=pd.read_csv('data.csv')
# fetch 1st five rows
df.head(5)
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.tail(5)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4

# %%
df.dtypes
# Out:
# Duration      int64
# Pulse         int64
# Maxpulse      int64
# Calories    float64
# dtype: object

# %%
# handling missing values
df.isnull()
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]

# %%
df.isnull().any(axis=1)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# Length: 169, dtype: bool

# %%
df.isnull().any
# Out:
# <bound method DataFrame.any of      Duration  Pulse  Maxpulse  Calories
# 0       False  False     False     False
# 1       False  False     False     False
# 2       False  False     False     False
# 3       False  False     False     False
# 4       False  False     False     False
# ..        ...    ...       ...       ...
# 164     False  False     False     False
# 165     False  False     False     False
# 166     False  False     False     False
# 167     False  False     False     False
# 168     False  False     False     False
#
# [169 rows x 4 columns]>

# %%
df.isnull().sum()
# Out:
# Duration    0
# Pulse       0
# Maxpulse    0
# Calories    5
# dtype: int64

# %%
df_filled=df.fillna(0)
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
## filling missing values with the mean of column
df['Duration_fillNA']=df['Duration'].fillna(df['Duration'].mean )
df
# Out:
#      Duration  Pulse  Maxpulse  Calories  Duration_fillNA
# 0          60    110       130     409.1               60
# 1          60    117       145     479.0               60
# 2          60    103       135     340.0               60
# 3          45    109       175     282.4               45
# 4          45    117       148     406.0               45
# ..        ...    ...       ...       ...              ...
# 164        60    105       140     290.8               60
# 165        60    110       145     300.0               60
# 166        60    115       145     310.2               60
# 167        75    120       150     320.4               75
# 168        75    125       150     330.4               75
#
# [169 rows x 5 columns]

# %%
#Renaming Columns
df=df.rename(columns={'Duration':'sale duration'})
df.head()
# Out:
#    sale duration  Pulse  Maxpulse  Calories  Duration_fillNA
# 0             60    110       130     409.1               60
# 1             60    117       145     479.0               60
# 2             60    103       135     340.0               60
# 3             45    109       175     282.4               45
# 4             45    117       148     406.0               45

# %%
## change datatypes
df['new value']=df['Pulse'].fillna(df['Pulse'].mean()).astype(float)
df.head()
# Out:
#    sale duration  Pulse  Maxpulse  Calories  Duration_fillNA  new value
# 0             60    110       130     409.1               60      110.0
# 1             60    117       145     479.0               60      117.0
# 2             60    103       135     340.0               60      103.0
# 3             45    109       175     282.4               45      109.0
# 4             45    117       148     406.0               45      117.0

# %%
df['new value']=df['Pulse'].apply(lambda x:x*2)
df.head()
# Out:
#    sale duration  Pulse  Maxpulse  Calories  Duration_fillNA  new value
# 0             60    110       130     409.1               60        220
# 1             60    117       145     479.0               60        234
# 2             60    103       135     340.0               60        206
# 3             45    109       175     282.4               45        218
# 4             45    117       148     406.0               45        234

# %%
##DATA AGGREGATING AND GROUPING
group_mean=df.groupby('sale duraton')['pule'].mean()
print(group_mean)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[15], line 2
#       1 ##DATA AGGREGATING AND GROUPING
# ----> 2 group_mean=df.groupby('sale duraton')['pule'].mean()
#       3 print(group_mean)
#
# File e:\udemy\venv\lib\site-packages\pandas\core\frame.py:9210, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9207 if level is None and by is None:
#    9208     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9210 return DataFrameGroupBy(
#    9211     obj=self,
#    9212     keys=by,
#    9213     axis=axis,
#    9214     level=level,
#    9215     as_index=as_index,
#    9216     sort=sort,
#    9217     group_keys=group_keys,
#    9218     observed=observed,
#    9219     dropna=dropna,
#    9220 )
#
# ...

# %%
import pandas as pd

data = {
    'Department': ['IT', 'HR', 'IT', 'HR', 'Finance'],
    'Salary': [50000, 40000, 60000, 45000, 70000],
    'Age': [25, 30, 28, 35, 40]
}

df = pd.DataFrame(data)
df
# Out:
#   Department  Salary  Age
# 0         IT   50000   25
# 1         HR   40000   30
# 2         IT   60000   28
# 3         HR   45000   35
# 4    Finance   70000   40

# %%
df.groupby('Department').agg({
    'Salary': ['mean', 'max'],
    'Age': 'mean'
})
# Out:
#              Salary          Age
#                mean    max  mean
# Department
# Finance     70000.0  70000  40.0
# HR          42500.0  45000  32.5
# IT          55000.0  60000  26.5

# %%
df.groupby('Department').sum()
df.groupby('Department').count()
df.groupby('Department').min()
df.groupby('Department').max()
# Out:
#             Salary  Age
# Department
# Finance      70000   40
# HR           45000   35
# IT           60000   28

# %%
df.groupby('Department').sum()
# Out:
#             Salary  Age
# Department
# Finance      70000   40
# HR           85000   65
# IT          110000   53

# %%
df.groupby('Department').count()
# Out:
#             Salary  Age
# Department
# Finance          1    1
# HR               2    2
# IT               2    2
